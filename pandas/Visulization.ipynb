# %% [markdown]
# <a href="https://colab.research.google.com/github/maithstartup/Notebooks-Practical-ML-Beginners/blob/master/pandas/Visulization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visulization with pandas.plot()

# %% [markdown]
# The plot method on Series and DataFrame is just a simple wrapper around plt.plot():

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))
print(df)
# Out:
#                    A         B         C         D
# 2000-01-01  0.144686 -0.151375 -2.262078 -1.115914
# 2000-01-02 -0.794076  0.154141  0.189049  0.397424
# 2000-01-03  0.442548  1.242138  0.520378 -0.263743
# 2000-01-04 -1.436584 -1.648669  1.761460 -0.281959
# 2000-01-05 -1.099283 -0.986981 -0.219085  0.765281
# 2000-01-06  2.044358 -1.756501 -0.569774  0.146662
# 2000-01-07  0.786230  0.577053 -0.281079  0.191152
# 2000-01-08  0.146413  1.618086  2.316164 -0.126549
# 2000-01-09 -0.627904  0.129101  1.851452 -0.603724
# 2000-01-10 -1.175105 -0.211468 -1.370617 -0.318530

# %%
df.plot( )

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()

# %%
df.plot(kind="bar")

# %%
df.plot.bar(stacked=True)

# %%
df.plot.barh(stacked=True)

# %%
df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.plot.hist(bins=20 )

# %%
df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.hist(bins=20)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()

# %%
df.plot()

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b',c='c' )

# %%
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b2e58e240>],
#       dtype=object)
